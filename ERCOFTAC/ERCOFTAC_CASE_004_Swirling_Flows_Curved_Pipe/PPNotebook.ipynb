# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Wo = 10.4
R = 0.0381

# %%
'''
-18 z = -1.3716 x = -0.9519 -1.0281
-10 z = 0.762 x 
-6 z = 0.4572 x 
-1 z = -0.0762 x 
22.5 x -0.072987 -0.002587 = z = 0.174886 0.20405
67.5 -0.3203 -0.291153 z = 0.422213 0.492613
112.5 x -0.67 -0.7 z = 0.422213 0.492613
157.5 x = -0.917412946357658 -0.987812566735018 z = 0.17488632859084607 0.20404680613706594
'''
D = 0.0762
#print(z_int,z_ext, x_int,x_ext)

# %%
#sd_-18

x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([0.71,0.825,0.916,0.956,1.007,1.034,1.08,1.108,1.108,1.12,1.121,1.112,1.106,1.065,1.012,0.97,0.915,0.825,0.75])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
df_star = pd.read_csv('sd-18_vel_ke.csv')
x_star = df_star['Line Probe: Centroid[X] (m)']
vel_star = df_star['Line Probe: Velocity[k] (m/s)']
x_star /=R
vel_star /= Wo
plt.scatter(x_star,vel_star,marker='X',c='r',linewidths=0.001,label='MOOSE-NS_neq')

plt.title('Fully developed inlet velocity profile')
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()

plt.grid()
plt.tight_layout()

plt.savefig('plots_fullyDevel_vel.pdf')

# %%
#sd_-18 (vertical)
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([0.971,1.091,1.141,1.211,1.212,1.230,1.172,1.143,1.103,1.082,1.071,1.044,1.022,1.005,0.962,0.921,0.884,0.783,0.663])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
###
df_star = pd.read_csv('axial_vel_sd-18_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
x_star = df_star['Points:0']
vel_star = df_star['vel:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
###
df_star = pd.read_csv('axial_vel_sd-18_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
x_star = df_star['Points:0']
vel_star = df_star['Velocity:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='s',c='b',linewidths=0.001,label='Star-CCM+')
##########
plt.title("s/D = -18, Outlet Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_sd18_vel.pdf')

# %%
#sd_-10 (vertical)
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([1.041,1.142,1.254,1.277,1.265,1.248,1.185,1.112,1.077,1.043,1.012,0.965,0.939,0.904,0.873,0.857,0.814,0.738,0.683])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
# #1
df_star = pd.read_csv('axial_vel_sd-10_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
x_star = df_star['Points:0']
vel_star = df_star['vel:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
#starsims
df_star = pd.read_csv('axial_vel_sd-10_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
x_star = df_star['Points:0']
vel_star = df_star['Velocity:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("s/D = -10 , Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_sd10_vel.pdf')

# %%
#sd_-6 (vertical)
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([1.111,1.292,1.332,1.321,1.313,1.281,1.241,1.183,1.094,1.064,0.964,0.882,0.821,0.803,0.803,0.783,0.744,0.665,0.576])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
#1
df_star = pd.read_csv('axial_vel_sd-6_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
x_star = df_star['Points:0']
vel_star = df_star['vel:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
df_star = pd.read_csv('axial_vel_sd-6_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
x_star = df_star['Points:0']
vel_star = df_star['Velocity:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("s/D = -6, Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_sd6_vel.pdf')

# %%
#sd_-1 (vertical)
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([1.311,1.334,1.328,1.314,1.283,1.259,1.224,1.174,1.180,1.063,0.988,0.885,0.779,0.643,0.588,0.564,0.526,0.491,0.425])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
#1
df_star = pd.read_csv('axial_vel_sd-1_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
x_star = df_star['Points:0']
vel_star = df_star['vel:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
df_star = pd.read_csv('axial_vel_sd-1_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
x_star = df_star['Points:0']
vel_star = df_star['Velocity:2']
vel_star /= -Wo
x_star += 0.9906
x_star /= R
plt.scatter(x_star,vel_star,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("s/D = -1, Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_sd1_vel.pdf')

# %%
# Import math Library
import math
from numpy import linalg as LA

#machinery to build orthonormal vector to compute axial velocity
rad = 0.457
Rad = 0.5332

angle = 22.5
z_int = rad*math.sin(math.radians(angle))
z_ext = Rad*math.sin(math.radians(angle))
x_int = -0.4952+rad*math.cos(math.radians(angle))
x_ext = -0.4952+Rad*math.cos(math.radians(angle))

vec_radial = np.array([z_ext-z_int,x_ext-x_int])
vec_axial_225 = np.array([-vec_radial[1]/vec_radial[0],1])
vec_axial_225 /= LA.norm(vec_axial_225)

######
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([0.811,0.891,1.021,1.065,1.1203,1.111,1.112,1.112,1.121,1.123,1.118,1.115,1.11,1.041,1.043,1.07,0.95,0.863,0.725])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')


#star
Wo = 10.4
R = 0.0381
#1
df_star = pd.read_csv('axial_vel_theta22.5_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
vel_vector = np.array([df_star['vel:2'],df_star['vel:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_225)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / R
#x_star += 0.9906
#x_star /= R
plt.scatter(x_star,vel_axial,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
df_star = pd.read_csv('axial_vel_theta22.5_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
vel_vector = np.array([df_star['Velocity:2'],df_star['Velocity:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_225)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / R
plt.scatter(x_star,vel_axial,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("theta = 22.5, Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_theta22.5_vel.pdf')

# %%
# Import math Library
import math
from numpy import linalg as LA

#machinery to build orthonormal vector to compute axial velocity
rad = 0.457 
Rad = 0.5332

angle = 67.5
z_int = rad*math.sin(math.radians(angle))
z_ext = Rad*math.sin(math.radians(angle))
x_int = -0.4952+rad*math.cos(math.radians(angle))
x_ext = -0.4952+Rad*math.cos(math.radians(angle))

vec_radial = np.array([z_ext-z_int,x_ext-x_int])
vec_axial_675 = np.array([-vec_radial[1]/vec_radial[0],1])
vec_axial_675 /= LA.norm(vec_axial_675)

######
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([0.96,1.05,1.1,1.11,1.15,1.155,1.16,1.15,1.08,1.04,1.011,0.991,0.965,0.927,0.913,0.905,0.869,0.809,0.734])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
#1
df_star = pd.read_csv('axial_vel_theta67.5_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
vel_vector = np.array([df_star['vel:2'],df_star['vel:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_675)
vel_axial /= -0.98*Wo
x_star = (df_star['arc_length'] - R ) / -R
#x_star += 0.9906
#x_star /= R
plt.scatter(x_star,vel_axial,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
df_star = pd.read_csv('axial_vel_theta67.5_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
vel_vector = np.array([df_star['Velocity:2'],df_star['Velocity:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_675)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / -R
plt.scatter(x_star,vel_axial,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("theta = 67.5, Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_theta67.5_vel.pdf')

# %%
# Import math Library
import math
from numpy import linalg as LA

#machinery to build orthonormal vector to compute axial velocity
rad = 0.457 
Rad = 0.5332

angle = 112.5
z_int = rad*math.sin(math.radians(angle))
z_ext = Rad*math.sin(math.radians(angle))
x_int = -0.4952+rad*math.cos(math.radians(angle))
x_ext = -0.4952+Rad*math.cos(math.radians(angle))

vec_radial = np.array([z_ext-z_int,x_ext-x_int])
vec_axial_1125 = np.array([-vec_radial[1]/vec_radial[0],1])
vec_axial_1125 /= LA.norm(vec_axial_1125)

######
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([1.065,1.131,1.191,1.213,1.215,1.223,1.154,1.135,1.087,1.039,1.011,0.965,0.937,0.935,0.92,0.912,0.891,0.826,0.758])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
#1
df_star = pd.read_csv('axial_vel_theta112.5_vertical.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
vel_vector = np.array([df_star['vel:2'],df_star['vel:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_1125)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / -R

plt.scatter(x_star,vel_axial,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
df_star = pd.read_csv('axial_vel_theta112.5_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
vel_vector = np.array([df_star['Velocity:2'],df_star['Velocity:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_1125)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / -R
plt.scatter(x_star,vel_axial,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("theta = 112.5, Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_theta112.5_vel.pdf')

# %%
# Import math Library
import math
from numpy import linalg as LA

#machinery to build orthonormal vector to compute axial velocity
rad = 0.457 
Rad = 0.5332

angle = 157.5
z_int = rad*math.sin(math.radians(angle))
z_ext = Rad*math.sin(math.radians(angle))
x_int = -0.4952+rad*math.cos(math.radians(angle))
x_ext = -0.4952+Rad*math.cos(math.radians(angle))

vec_radial = np.array([z_ext-z_int,x_ext-x_int])
vec_axial_1575 = np.array([-vec_radial[1]/vec_radial[0],1])
vec_axial_1575 /= LA.norm(vec_axial_1575)

######
x_exp = np.array([-0.938,-0.875,-0.797,-0.708,-0.625,-0.5,-0.375,-0.25,-0.125,0,0.125,0.25,0.375,0.5,0.625,0.708,0.797,0.875,0.938])
v_exp = np.array([1.071,1.181,1.212,1.241,1.256,1.23,1.166,1.149,1.103,0.946,0.863,0.816,0.825,0.76,0.745,0.723,0.709,0.695,0.632])
plt.scatter(x_exp,v_exp,c='k',label = 'Experiment')

#star
Wo = 10.4
R = 0.0381
#1
df_star = pd.read_csv('axial_vel_theta157.5_vertical_v3.csv')
df_star = df_star.drop_duplicates(subset=['vel:2'])
vel_vector = np.array([df_star['vel:2'],df_star['vel:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_1575)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / -R

plt.scatter(x_star,vel_axial,marker='D',c='r',linewidths=0.001,label='MOOSE-NS_neq')
#2
df_star = pd.read_csv('axial_vel_theta157.5_vertical_star.csv')
df_star = df_star.drop_duplicates(subset=['Velocity:2'])
vel_vector = np.array([df_star['Velocity:2'],df_star['Velocity:0']])
vel_axial = np.matmul(np.transpose(vel_vector),vec_axial_1575)
vel_axial /= -Wo
x_star = (df_star['arc_length'] - R ) / -R
plt.scatter(x_star,vel_axial,marker='s',c='b',linewidths=0.001,label='Star-CCM+')

plt.title("theta = 157.5, Axial Velocity, Vertical Plane")
plt.xlabel(r'$\mathrm{r^*}$', fontsize=14)
plt.ylabel(r'$\mathrm{U_z^*}$', fontsize=14)
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('plots_theta157.5_vel.pdf')
